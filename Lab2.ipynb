# %% [markdown]
# To find the sum of square root of any three numbers.

# %%
import math
num1=int(input("Number1:"))
num2=int(input("Number2:"))
num3=int(input("Number3:"))
sqrt1 = math.sqrt(num1)
sqrt2 = math.sqrt(num2)
sqrt3 = math.sqrt(num3)
res =int (sqrt1 + sqrt2 + sqrt3)
print(f"The sum of the square roots of",num1,num2,"and",num3," is",res)
# Out:
# Number1:5
# Number2:4
# Number3:3
# The sum of the square roots of 5 4 and 3  is 5

# %% [markdown]
# To solve the quadratic equation.

# %%
import math
a = int(input("A:"))
b = int(input("B:"))
c = int(input("C:"))
x = b**2 - 4*a*c

if x > 0:
    root1 = (-b + math.sqrt(x)) / (2*a)
    root2 = (-b - math.sqrt(x)) / (2*a)
    print(f"The roots are real and different: {root1} and {root2}")
elif x == 0:
    root = -b / (2*a)
    print("The root is real and the same: ",root)
else:
    r = -b / (2*a)
    i = math.sqrt(-x) / (2*a)
    print("The roots are complex and different: ",r,"+",i,"i and",r"-",i,"i")
# Out:
# A:3
# B:1
# C:8
# The roots are complex and different:  -0.16666666666666666 + 1.6244657241348273 i and - 1.6244657241348273 i

# %% [markdown]
# Find GCD of two numbers

# %%
a=int(input("Number 1:"))
b=int(input("Number 2:"))
while (a!=b):
  if a>b:
    c=a-b
    a=b
    b=c
  else:
    c=b-a
    b=a
    a=c
print(c)
# Out:
# Number 1:7
# Number 2:5
# 1

# %% [markdown]
# Compute a)5 to the power of 8 b)square root of 400 c)exponent of 5 d)Logarithm of 625 base 5

# %%
power = pow(5,8)
sqrt = math.sqrt(400)
exp = math.exp(5)
log = math.log(625, 5)
print(f"5 to the power of 8: {power}")
print(f"Square root of 400: {sqrt}")
print(f"Exponent of 5: {exp}")
print(f"Logarithm of 625 base 5: {log}")
# Out:
# 5 to the power of 8: 390625
# Square root of 400: 20.0
# Exponent of 5: 148.4131591025766
# Logarithm of 625 base 5: 4.0

# %% [markdown]
# Compute a)sin of 60 degree b)cos of pi c)sin(0.8660254037844386) d)tan of 90 degree

# %%
import math

radians_60 = math.radians(60)
result_a = math.sin(radians_60)
print(f"The sine of 60 degrees is: {result_a}")

result_b = math.cos(math.pi)
print(f"The cosine of π radians is: {result_b}")

result_c = math.sin(0.8660254037844386)
print(f"The sine of 0.8660254037844386 radians is: {result_c}")

radians_90 = math.radians(90)
result_d = math.tan(radians_90)
print(f"The tangent of 90 degrees is: {result_d}")

# %% [markdown]
# Define a sum function with two parameters and call the function

# %%
def sum(a, b):
    return a + b

result = sum(5, 3)
print(result)

# %% [markdown]
# WAP to reverse a given string.

# %%
def reverse_string(s):
    return s[::-1]

input_string = input("Enter a string: ")
reversed_string = reverse_string(input_string)
print(reversed_string)

# %% [markdown]
# Write a function to calculate the power of a number using recursion

# %%
def power(base, exponent):
    if exponent == 0:
        return 1

    elif exponent < 0:
        return 1 / power(base, -exponent)

    else:
        return base * power(base, exponent - 1)

print(power(2, 3))
print(power(5, -2))
print(power(7, 0))

# %% [markdown]
# Convert Decimal number to Binary

# %%
def decimal_to_binary(n):
    if n == 0:
        return "0"
    elif n == 1:
        return "1"
    else:
        return decimal_to_binary(n // 2) + str(n % 2)

num = int(input("Enter a decimal number: "))
binary_representation = decimal_to_binary(num)
print(f"The binary representation of {num} is {binary_representation}")

# %% [markdown]
# Write a program in Python to check if a number is Krishnamurthy number.

# %%
import math

def is_krishnamurthy_number(n):

    def factorial(digit):
        return math.factorial(digit)
    str_num = str(n)
    sum_of_factorials = sum(factorial(int(digit)) for digit in str_num)
    return sum_of_factorials == n

number = int(input("Enter a number: "))

if is_krishnamurthy_number(number):
    print(f"{number} is a Krishnamurthy number.")
else:
    print(f"{number} is not a Krishnamurthy number.")

# %% [markdown]
# Write a program in Python to find the sum of digits of a number.

# %%
def sum_of_digits(n):
    if n == 0:
        return 0
    else:
        return n % 10 + sum_of_digits(n // 10)
num = int(input("Enter a number: "))
result = sum_of_digits(num)
print(f"The sum of the digits of {num} is {result}.")

# %% [markdown]
# Write a program in Python that prompts the user to input a number and prints its
# multiplication table.

# %%
def print_multiplication_table(n, up_to=10):
    for i in range(1, up_to + 1):
        print(f"{n} x {i} = {n * i}")

num = int(input("Enter a number: "))

print(f"Multiplication table of {num}:")
print_multiplication_table(num)
# Out:
# Enter a number: 5
# Multiplication table of 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# Write a program in Python that prompts the user to input a number and prints its
# multiplication table.

# %%
# Out:
# Enter the number of terms: 5
# The series up to 5 terms is:
# 1, 2, 6, 24, 120

# %% [markdown]
# Write a Python program to print the first 6 terms of a geometric sequence starting with 2
# and having a common ratio of 3.

# %%
def print_geometric_sequence(start, ratio, terms):
    current = start
    for _ in range(terms):
        print(current, end=", " if _ < terms - 1 else "\n")
        current *= ratio

start_term = 2
common_ratio = 3
number_of_terms = 6

print(f"The first {number_of_terms} terms of the geometric sequence are:")
print_geometric_sequence(start_term, common_ratio, number_of_terms)

# %% [markdown]
# Print the series upto N terms: 1,2,6,24,120,720 …

# %%
import math

def print_factorial_series(n):
    for i in range(1, n + 1):
        print(math.factorial(i), end=", " if i < n else "\n")

n = int(input("Enter the number of terms: "))

print(f"The series up to {n} terms is:")
print_factorial_series(n)
# Out:
# Enter the number of terms: 6
# The series up to 6 terms is:
# 1, 2, 6, 24, 120, 720

# %% [markdown]
# Write a Python program that prompts the user to enter a base number and an exponent,
# and then calculates the power of the base to the exponent. The program should not use the
# exponentiation operator (**) or the math.pow() function.

# %%
def calculate_power(base, exponent):
    result = 1

    if exponent < 0:
        base = 1 / base
        exponent = -exponent
    for _ in range(exponent):
        result *= base
    return result


base = float(input("Enter the base number: "))
exponent = int(input("Enter the exponent: "))


power_result = calculate_power(base, exponent)
print(f"{base} raised to the power of {exponent} is {power_result}.")
